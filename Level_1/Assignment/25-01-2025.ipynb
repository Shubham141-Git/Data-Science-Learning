# %%
#question-1-->
# Creating the empty set

##my solution 
nameSet = set()




def mark_attendance():
 name=input("enter student name")
 while(name.lower()!="stop"):
     nameSet.add(name)
     name=input("enter student name")
 if(name=="stop"):
   print(nameSet)

mark_attendance()

#chatgpt 

'''def mark_attendance():
    attendance_set = set()

    while True:
        name = input("Enter student name: ")

        if name.lower() == "stop":
            break

        attendance_set.add(name)

    print("Total unique students:", len(attendance_set))
    print("Attendance Set:", attendance_set)


mark_attendance()
'''

#Question-2

#2. The Restaurant Bill Splitter
''' my code
def split_bills(item_prices,people,tax=0.10,tip=0.50):
  totalsum=sum(item_prices)
  totalpeople=people
  x=tax+totalsum+tip
  split=x/totalpeople
  return split

split_bills([12,23,34,45,56,7,43534,422],5)
'''
'''
chatgptcode
def split_bill(items_prices, people, tax=0.05, tip=0.10):
    subtotal = sum(items_prices)
    
    tax_amount = subtotal * tax
    tip_amount = subtotal * tip
    
    total = subtotal + tax_amount + tip_amount
    
    return total / people
'''
# Out:
# {'sfgdf'}
# 8830.6
