# %% [markdown]
# ##List

# %%
## Non-Primitive data types: List, Tuple, Set, Dictionary   

#List: ordered, mutable, allows duplicates
my_list=[1,2,3,4,5]
print(my_list)
print(type(my_list))            
#properties of list
print(my_list[0])                #accessing element by index
my_list[0]=10                    #modifying element by index
print(my_list)  
my_list.append(6)                #adding element to the end of the list
print(my_list)  
my_list.insert(0,0)             #adding element at specific index
print(my_list)
my_list.remove(10)             #removing element by value
print(my_list)  
my_list.pop()                  #removing last element
print(my_list)
my_list.pop(0)               #removing element by index
print(my_list)  

''' ✅ Python List: Properties & Specifications
🔹 What is a List?

A list is a built-in Python data structure used to store multiple values in a single variable.

my_list = [1, 2, 3, "apple", True]

🔹 Properties of a Python List
1️⃣ Ordered

Elements have a fixed order

Order is preserved

lst = [10, 20, 30]
print(lst[0])  # 10

2️⃣ Mutable (Changeable)

You can modify elements after creation

lst = [1, 2, 3]
lst[1] = 99
print(lst)  # [1, 99, 3]

3️⃣ Allows Duplicate Values

Same value can appear multiple times

lst = [1, 2, 2, 3]

4️⃣ Can Store Mixed Data Types

A single list can store different types

lst = [10, "Python", 3.14, True]

5️⃣ Indexed

Uses 0-based indexing

lst = ["a", "b", "c"]
print(lst[1])  # b

6️⃣ Dynamic Size

Size can grow or shrink dynamically

lst = []
lst.append(10)
lst.append(20)

7️⃣ Supports Nesting

Lists can contain other lists

lst = [[1, 2], [3, 4]]

8️⃣ Iterable

Can be looped over using for

for item in lst:
    print(item)

🔹 Specifications of a Python List
Specification	Description
Data Type	list
Syntax	[]
Indexing	Starts from 0
Mutability	Mutable
Order	Preserved
Duplicates	Allowed
Nesting	Allowed
Length	len(list)
🔹 Common List Methods (Very Important)
Method	Use
append()	Add item at end
insert()	Add item at index
remove()	Remove by value
pop()	Remove by index and by deafault last element and the index of the elements also changes
clear()	Remove all items
sort()	Sort list
reverse()	Reverse order
count()	Count occurrences
index()	Find index
🔹 Example with Methods
lst = [3, 1, 2]

lst.append(4)
lst.sort()
lst.remove(1)

print(lst)  # [2, 3, 4]

🔹 List vs Tuple (Quick Comparison)
Feature	List	Tuple
Mutable	Yes	No
Syntax	[]	()
Performance	Slower	Faster
Use Case	Dynamic data	Fixed data
🔑 One-line Definition (Exam Friendly)

A list in Python is an ordered, mutable, and indexed collection that allows duplicate and heterogeneous elements.'''


#lAST VALUE OF THE LIST
my_list=[1,2,3,4,5]
print(my_list[-1]) #accessing last element by negative indexing because index starts from 0 from start and -1  from last element
print(my_list[-2]) #accessing second last element by negative indexing  
print(my_list[-3]) #accessing third last element by negative indexing   

#using len() function to access last element
print(my_list[len(my_list)-1]) #accessing last element using len() function

''''1️⃣ append() → Add item at end
fruits = ["apple", "banana"]
fruits.append("mango")
print(fruits)


Output

['apple', 'banana', 'mango']

2️⃣ insert() → Add item at a specific index
fruits = ["apple", "banana"]
fruits.insert(1, "orange")
print(fruits)


Output

['apple', 'orange', 'banana']

3️⃣ remove() → Remove by value
fruits = ["apple", "banana", "mango"]
fruits.remove("banana")
print(fruits)


Output

['apple', 'mango']


⚠️ Removes first occurrence only

4️⃣ pop() → Remove by index
fruits = ["apple", "banana", "mango"]
fruits.pop(1)
print(fruits)


Output

['apple', 'mango']


🔹 Without index (removes last item):

fruits.pop()

5️⃣ clear() → Remove all items
fruits = ["apple", "banana", "mango"]
fruits.clear()
print(fruits)


Output

[]

6️⃣ sort() → Sort the list
numbers = [3, 1, 4, 2]
numbers.sort()
print(numbers)


Output

[1, 2, 3, 4]


🔹 Reverse sort:

numbers.sort(reverse=True)

7️⃣ reverse() → Reverse order
numbers = [1, 2, 3, 4]
numbers.reverse()
print(numbers)


Output

[4, 3, 2, 1]

8️⃣ count() → Count occurrences
numbers = [1, 2, 2, 3, 2]
print(numbers.count(2))


Output

3

9️⃣ index() → Find index of value
fruits = ["apple", "banana", "mango"]
print(fruits.index("banana"))


Output

1

'''
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# 1
# [10, 2, 3, 4, 5]
# [10, 2, 3, 4, 5, 6]
# [0, 10, 2, 3, 4, 5, 6]
# [0, 2, 3, 4, 5, 6]
# [0, 2, 3, 4, 5]
# [2, 3, 4, 5]
# 5
# 4
# 3
# 5
# ...

# %% [markdown]
# ## Dictionary

# %%
# Dictionary: unordered, mutable, key-value pairs, no duplicates
my_dict={"name":"John","age":30,"city":"New York"}  
print(my_dict)
print(type(my_dict))  

#properties of dictionary
print(my_dict["name"])  #accessing value by key
print(my_dict["age"])   #accessing value by key
print(my_dict["city"])  #accessing value by key
my_dict["age"]=31     #modifying value by key
print(my_dict)
my_dict["country"]="USA"  #adding new key-value pair
print(my_dict)
my_dict.pop("city")      #removing key-value pair by key
print(my_dict)
my_dict.clear()         #removing all key-value pairs
print(my_dict)  
''' ✅ Python Dictionary: Properties & Specifications
🔹 What is a Dictionary   
?
A dictionary in Python is a collection of key-value pairs that is unordered, mutable, and indexed. Each key in a dictionary is unique and maps to a value. Dictionaries are defined using curly braces {} and are useful for storing and retrieving data efficiently.

🔹 Properties of a Python Dictionary
1️⃣ Unordered

Keys and values are not stored in any particular order.

2️⃣ Mutable

Values can be changed after creation.

3️⃣ Indexed

Values are accessed using keys.

4️⃣ Unique Keys

Each key must be unique within a dictionary.

5️⃣ Heterogeneous Values

Values can be of any data type (int, string, list, etc.).

6️⃣ No Duplicate Keys

If duplicate keys are added, the last value assigned to that key will be retained.

7️⃣ Dynamic Size

Size can grow or shrink dynamically.

8️⃣ Iterable

Can be looped over using for loops.

🔹 Specifications of a Python Dictionary
Specification	Description
Data Type	dict
Syntax	{}
Indexing	By Key
Mutability	Mutable
Uniqueness	Keys must be unique
Duplicates	Values can be duplicated
Length	len(dict)
🔹 Common Dictionary Methods (Very Important)
Method	Use
keys()	Get all keys
values()	Get all values
items()	Get all key-value pairs
get()	Get value by key (safe)
pop()	Remove by key and return value
clear()	Remove all items
'''
#update()	Update with another dictionary
my_dict={"name":"John","age":30,"city":"New York"}
my_dict.update({"age":31,"country":"USA"})  #updating existing key and adding new key-value pair
print(my_dict)  

''' ✅ Python Dictionary Methods: Essential Functions
🔹 keys() → Get all keys'''

print(my_dict.keys())       

'''Output
dict_keys(['name', 'age', 'city', 'country'])   '''

'''Great choice — Dictionary is a super important Python topic 🔑🐍
Here it is clean, structured, and exam-ready.

✅ Python Dictionary: Properties & Specifications
🔹 What is a Dictionary?

A dictionary is a built-in Python data structure that stores data in key–value pairs.

student = {
    "name": "Rahul",
    "age": 21,
    "marks": 85
}

🔹 Properties of a Python Dictionary
1️⃣ Stores Data as Key–Value Pairs

Each value is accessed using a unique key

print(student["name"])  # Rahul

2️⃣ Unordered (Logically)

Items are not indexed

Accessed by keys, not position
(Insertion order is preserved in Python 3.7+)

3️⃣ Mutable

You can add, update, or delete items

student["age"] = 22
student["city"] = "Pune"

4️⃣ Keys Must Be Unique

Duplicate keys overwrite previous values

d = {"a": 1, "a": 2}
print(d)  # {'a': 2}

5️⃣ Keys Must Be Immutable

Allowed: int, float, str, tuple

Not allowed: list, set, dict

d = {(1, 2): "ok"}   # valid
# d = {[1, 2]: "no"} # invalid

6️⃣ Values Can Be Any Data Type

Can store numbers, strings, lists, tuples, even other dictionaries

data = {
    "id": 101,
    "skills": ["Python", "SQL"],
    "profile": {"level": "Beginner"}
}

7️⃣ Allows Duplicate Values
d = {"a": 1, "b": 1}

8️⃣ Dynamic Size

Grows or shrinks automatically

d["new_key"] = 100
del d["a"]

9️⃣ Iterable

Can loop through keys, values, or items

for key in d:
    print(key)

🔹 Specifications of a Python Dictionary
Specification	Description
Data Type	dict
Syntax	{}
Storage	Key–Value pairs
Keys	Unique & Immutable
Values	Any data type
Mutability	Mutable
Indexing	No (uses keys)
Nesting	Allowed
Length	len(dictionary)
🔹 Common Dictionary Methods
Method	Purpose
keys()	Get all keys
values()	Get all values
items()	Get key-value pairs
get()	Safe value access
update()	Add / update items
pop()	Remove by key
clear()	Remove all items
🔹 Dictionary vs List (Quick Comparison)
Feature	Dictionary	List
Data storage	Key–Value	Single values
Access	By key	By index
Order	Insertion order (3.7+)	Ordered
Mutability	Mutable	Mutable
Lookup speed	Fast (O(1))	Slower
🔑 One-line Definition (Exam Friendly)

A dictionary in Python is a mutable collection of key–value pairs where keys are unique and immutable.'''
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
register={
    
    "id-1":["Shubham",30,"Pune","Data Scientist", "Twenty lakhs", "twenty Crores"],
    "id-2":["Rahul",25,"Mumbai","Software Engineer", "three lakhs", "thirty thousands"]
    
    }

# %%
##properties examle of dictionary
'''1️⃣ keys() → Get all keys
student = {"name": "Amit", "age": 21, "marks": 85}

print(student.keys())


Output

dict_keys(['name', 'age', 'marks'])

2️⃣ values() → Get all values
student = {"name": "Amit", "age": 21, "marks": 85}

print(student.values())


Output

dict_values(['Amit', 21, 85])

3️⃣ items() → Get key–value pairs
student = {"name": "Amit", "age": 21, "marks": 85}

print(student.items())


Output

dict_items([('name', 'Amit'), ('age', 21), ('marks', 85)])

4️⃣ get() → Safe value access
student = {"name": "Amit", "age": 21}

print(student.get("age"))
print(student.get("city"))
print(student.get("city", "Not Found"))


Output

21
None
Not Found


✅ No error if key doesn’t exist

5️⃣ update() → Add / update items
student = {"name": "Amit", "age": 21}

student.update({"age": 22, "city": "Mumbai"})
print(student)


Output

{'name': 'Amit', 'age': 22, 'city': 'Mumbai'}

6️⃣ pop() → Remove by key
student = {"name": "Amit", "age": 21}

student.pop("age")
print(student)


Output

{'name': 'Amit'}


⚠️ Error if key not found (unless default is given)

student.pop("city", "Not Found")

7️⃣ clear() → Remove all items
student = {"name": "Amit", "age": 21}

student.clear()
print(student)


Output

{}

🧠 Quick Cheat Sheet
Method	Example
keys()	dict.keys()
values()	dict.values()
items()	dict.items()
get()	dict.get(key, default)
update()	dict.update({...})
pop()	dict.pop(key)
clear()	dict.clear()
🔑 Key takeaway

Use get() when you don’t want errors

Use items() when looping over keys and values together

If you want, I can next show:

looping through dictionary

nested dictionary examples

dictionary comprehension

common interview mistakes

Just tell me 😊

yes

Awesome 👍 Let’s level up step-by-step.
I’ll cover all 4 things in a clean, beginner-friendly way.

1️⃣ Looping through a Dictionary 🔁
Loop through keys
student = {"name": "Amit", "age": 21, "marks": 85}

for key in student:
    print(key)

Loop through values
for value in student.values():
    print(value)

Loop through keys and values together (most used)
for key, value in student.items():
    print(key, ":", value)

2️⃣ Nested Dictionary (Dictionary inside Dictionary) 🧩
students = {
    "student1": {"name": "Amit", "age": 21},
    "student2": {"name": "Neha", "age": 22}
}

print(students["student1"]["name"])   # Amit

Looping through nested dictionary
for student_id, info in students.items():
    print(student_id)
    for key, value in info.items():
        print(" ", key, ":", value)

3️⃣ Dictionary Comprehension ⚡
Create dictionary of squares
squares = {x: x*x for x in range(1, 6)}
print(squares)


Output

{1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

With condition
even_squares = {x: x*x for x in range(1, 6) if x % 2 == 0}
print(even_squares)

4️⃣ Common Dictionary Mistakes 🚫
❌ Accessing missing key directly
print(student["city"])  # KeyError

✅ Correct way
print(student.get("city", "Not Available"))

❌ Using mutable type as key
# d = {[1, 2]: "value"}  # Error

✅ Correct
d = {(1, 2): "value"}

❌ Modifying dictionary while looping
# for key in student:
#     student.pop(key)   # RuntimeError

🏆 Final Summary
Topic	Key Point
Looping	Use items()
Nested dict	Access with multiple keys
Comprehension	Compact & powerful
Safe access	Use get()
Keys	Must be immutable'''
# Out:
# '1️⃣ keys() → Get all keys\nstudent = {"name": "Amit", "age": 21, "marks": 85}\n\nprint(student.keys())\n\n\nOutput\n\ndict_keys([\'name\', \'age\', \'marks\'])\n\n2️⃣ values() → Get all values\nstudent = {"name": "Amit", "age": 21, "marks": 85}\n\nprint(student.values())\n\n\nOutput\n\ndict_values([\'Amit\', 21, 85])\n\n3️⃣ items() → Get key–value pairs\nstudent = {"name": "Amit", "age": 21, "marks": 85}\n\nprint(student.items())\n\n\nOutput\n\ndict_items([(\'name\', \'Amit\'), (\'age\', 21), (\'marks\', 85)])\n\n4️⃣ get() → Safe value access\nstudent = {"name": "Amit", "age": 21}\n\nprint(student.get("age"))\nprint(student.get("city"))\nprint(student.get("city", "Not Found"))\n\n\nOutput\n\n21\nNone\nNot Found\n\n\n✅ No error if key doesn’t exist\n\n5️⃣ update() → Add / update items\nstudent = {"name": "Amit", "age": 21}\n\nstudent.update({"age": 22, "city": "Mumbai"})\nprint(student)\n\n\nOutput\n\n{\'name\': \'Amit\', \'age\': 22, \'city\': \'Mumbai\'}\n\n6️⃣ pop() → Remove by ke
# ...

# %%
govt_sys={
    101:["Shubham"],
    102:["Amit"],
    103:["HP"]
}

govt_sys.get(101) #-->accesselement

# get does not gves error if no key is present

govt_sys.get(1233,"Key not present") #--> Will print key not present because key id not present

govt_sys.keys() #--> can be converted into list using type casting
govt_sys.values()

#cinverting into list
print(list(govt_sys.values()))
# Out:
# [['Shubham'], ['Amit'], ['HP']]

# %%
#Mutable--> Something which can be changed
#Immutaablr--> Somethig which canot be changed

# %% [markdown]
# ## Tuple

# %%
#Tuple(Immutable): 

#tuple properties
dob=(17,"June",1995)

dob[1]="sdgdf" #--> Will throw error since tuple is immutable and values will not be changed

# %%
##Nested dictonary,using a tuple insde dictionary
register01={

    101:{
        "Name": "Shubham",
        "DOB":(17,"June",1997),
        "Phone": 7020030551,
        "Bank balance": "10 Crores"
    },
  102:{
        "Name": "Shubham",
        "DOB":(17,"June",1997),
        "Phone": 7020030551,
        "Bank balance": "10 Crores"
    }
}

# %% [markdown]
# ## Set

# %%
#Set
#Properties of set
#it is unordered

guests={"a","b","c","d"}
print(guests)

#How to create the empty set

a=set()
# Out:
# {'a', 'b', 'd', 'c'}

# %%
#how to add element to set

# %%
'''🔹 What is a Set?

A set is a built-in Python data structure used to store unique elements.

my_set = {1, 2, 3, 4}

🔑 Core Properties of Set
1️⃣ Unordered

No fixed order

No indexing or slicing

s = {10, 20, 30}
# print(s[0]) ❌ Error

2️⃣ No Duplicate Elements

Automatically removes duplicates

s = {1, 2, 2, 3}
print(s)   # {1, 2, 3}

3️⃣ Mutable (Set itself is mutable)

You can add or remove elements

s = {1, 2}
s.add(3)

4️⃣ Elements Must Be Immutable

Allowed: int, float, str, tuple

Not allowed: list, set, dict

s = {(1, 2), 3}   # valid
# s = {[1, 2]}    # invalid

5️⃣ Not Indexed

Access elements using loops, not index

for item in s:
    print(item)

6️⃣ Supports Mathematical Set Operations

Union, Intersection, Difference

a = {1, 2, 3}
b = {3, 4, 5}

print(a | b)   # Union
print(a & b)   # Intersection
print(a - b)   # Difference

7️⃣ Dynamic Size

Grows or shrinks automatically

s.add(10)
s.remove(2)

8️⃣ Fast Membership Testing

Very fast in operation (O(1))

print(3 in s)

9️⃣ Iterable

Can be looped over

for x in s:
    print(x)

📋 Quick Summary Table
Property	Description
Ordered	❌ No
Duplicates	❌ Not allowed
Indexed	❌ No
Mutable	✅ Yes
Elements	Immutable only
Nesting	❌ (use frozenset)
Lookup speed	Very fast
🆚 Set vs List (Quick)
Feature	Set	List
Duplicates	❌	✅
Order	❌	✅
Indexing	❌	✅
Membership check	Fast	Slower
🏆 One-line Definition (Exam-friendly)

A set in Python is an unordered, mutable collection of unique and immutable elements.




✅ Properties of a Python Set

Unordered

Elements have no fixed order.

No Duplicate Elements

A set automatically removes duplicate values.

Mutable

Elements can be added or removed after creation.

Elements Must Be Immutable

Only immutable types (int, float, string, tuple) can be stored.

Not Indexed

Elements cannot be accessed using an index.

Iterable

Can be traversed using loops.

Dynamic Size

The size of a set can grow or shrink.

Supports Set Operations

Union, intersection, difference, and symmetric difference.

Fast Membership Testing

Checking membership using in is very fast.






1️⃣ Unordered
s = {10, 20, 30}
print(s)


➡ Order may change every time you run it.

2️⃣ No Duplicate Elements
s = {1, 2, 2, 3}
print(s)


Output

{1, 2, 3}

3️⃣ Mutable (Can be changed)
s = {1, 2}
s.add(3)
print(s)

4️⃣ Elements Must Be Immutable
s = {1, "hello", (2, 3)}   # valid


❌ Invalid:

# s = {[1, 2]}   # Error

5️⃣ Not Indexed
s = {10, 20, 30}
# print(s[0])   # Error

6️⃣ Iterable
s = {5, 10, 15}

for item in s:
    print(item)

7️⃣ Dynamic Size
s = {1, 2, 3}
s.remove(2)
print(s)

8️⃣ Supports Set Operations
a = {1, 2, 3}
b = {3, 4, 5}

print(a | b)   # Union
print(a & b)   # Intersection
print(a - b)   # Difference

9️⃣ Fast Membership Testing
s = {10, 20, 30}
print(20 in s)


Output

True



'''

# %%
# We can convert list to set
